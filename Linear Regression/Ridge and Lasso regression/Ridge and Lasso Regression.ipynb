# %% [markdown]
# ## Algerian Forest Fires Dataset
# Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attribues and 1 output attribue (class)
# The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.

# %% [markdown]
# ### Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv(r'Algerian_forest_fires_dataset_UPDATE.csv',header=1)
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI    Classes
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4  not fire
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0  not fire
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# ## Data Cleaning

# %%
dataset.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws  ...   DMC      DC   ISI   BUI      FWI Classes
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  ...   NaN     NaN   NaN   NaN      NaN       NaN
# 167                             14    07  2012          37   37   18  ...  12.9  14.6 9  12.5  10.4  fire          NaN
#
# [2 rows x 14 columns]

# %%
dataset.loc[:122,'Region']=0
dataset.loc[122:,'Region']=1

df=dataset

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI    Classes    Region
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5  not fire        0.0
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4  not fire        0.0
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire        0.0
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0  not fire        0.0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5  not fire        0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df['Region']=df['Region'].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI    Classes    Region
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5  not fire          0
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4  not fire          0
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire          0
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0  not fire          0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5  not fire          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 28.0+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws  ...      DC   ISI   BUI      FWI Classes   Region
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  ...     NaN   NaN   NaN      NaN       NaN      1
# 167                             14    07  2012          37   37   18  ...  14.6 9  12.5  10.4  fire          NaN      1
#
# [2 rows x 15 columns]

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI    Classes    Region
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5  not fire          0
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4  not fire          0
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire          0
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0  not fire          0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5  not fire          0

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  FWI  Classes    Region
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  FWI  Classes         1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 27.7+ KB

# %%
df[['day','month','year','Temperature','RH','Ws']]=df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
objects=[feature for feature in df.columns if df[feature].dtypes=='O'] # O stands for object.
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for i in objects:
    if i != 'Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  Region
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire          0
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire          0
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire          0
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire          0
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire          0

# %%
df.describe()
# Out:
#               day       month    year  Temperature  ...         ISI         BUI         FWI      Region
# count  243.000000  243.000000   243.0   243.000000  ...  243.000000  243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263  ...    4.742387   16.690535    7.035391    0.497942
# std      8.842552    1.114793     0.0     3.628039  ...    4.154234   14.228421    7.440568    0.501028
# min      1.000000    6.000000  2012.0    22.000000  ...    0.000000    1.100000    0.000000    0.000000
# 25%      8.000000    7.000000  2012.0    30.000000  ...    1.400000    6.000000    0.700000    0.000000
# 50%     16.000000    8.000000  2012.0    32.000000  ...    3.500000   12.400000    4.200000    0.000000
# 75%     23.000000    8.000000  2012.0    35.000000  ...    7.250000   22.650000   11.450000    1.000000
# max     31.000000    9.000000  2012.0    42.000000  ...   19.000000   68.000000   31.100000    1.000000
#
# [8 rows x 14 columns]

# %%
# df.to_csv('Algerian_Forest_Fires_Cleaned_Dataset.csv',index=False)

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Algerian_Forest_Fires_Cleaned_Dataset.csv',
#  'Algerian_forest_fires_dataset_UPDATE.csv',
#  'economic_index.csv',
#  'height-weight.csv',
#  'Linear Regression (Annual Medical Expenditure Estimator).ipynb',
#  'medical.csv',
#  'Multiple Linear Regression.ipynb',
#  'Ridge and Lasso Regression.ipynb',
#  'Simple Linear Regression.ipynb']

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Algerian_Forest_Fires_Cleaned_Dataset.csv',
#  'Algerian_forest_fires_dataset_UPDATE.csv',
#  'economic_index.csv',
#  'height-weight.csv',
#  'Linear Regression (Annual Medical Expenditure Estimator).ipynb',
#  'medical.csv',
#  'Multiple Linear Regression.ipynb',
#  'Ridge and Lasso Regression.ipynb',
#  'Simple Linear Regression.ipynb']

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_c=df.drop(['day','month','year'],axis=1)

# %%
df_c['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df_c['Classes']=df_c['Classes'].str.strip() 
df_c['Classes']=np.where(df_c['Classes']=='not fire',0,1)
# OR
# df_c['Classes']=np.where(df_c['Classes'].str.contains('not fire'),0,1)

# %%
df_c.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_c['Classes'].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
df_c.to_csv('Algerian_Forest_Fires_Cleaned_Dataset.csv',index=False)

# %%
plt.style.use('seaborn')
df_c.hist(bins=50,figsize=(20,15));

# %%
percentage=df_c['Classes'].value_counts(normalize=True)*100

# %%
classLabel=['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classLabel,autopct='%1.1f%%')
plt.title('Pie Chart of Classes');

# %%
df_c.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC  ...       ISI       BUI       FWI   Classes    Region
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  ...  0.603871  0.459789  0.566670  0.516015  0.269555
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873  ... -0.686667 -0.353841 -0.580957 -0.432161 -0.402682
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548  ...  0.008532  0.031438  0.032368 -0.069964 -0.181160
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906  ... -0.347484 -0.299852 -0.324422 -0.379097 -0.040013
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  ...  0.740007  0.592011  0.691132  0.769492  0.222241
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  ...  0.680454  0.982248  0.875864  0.585658  0.192089
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  ...  0.508643  0.941988  0.739521  0.511123 -0.078734
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  ...  1.000000  0.644093  0.922895  0.735197  0.263197
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  ...  0.644093  1.000000  0.857973  0.586639  0.089408
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  ...  0.922895  0.857973  1.000000  0.719216  0.197102
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  ...  0.735197  0.586639  0.719216  1.000000  0.162347
# Region          0.269555 -0.402682 -0.181160 -0.040013  0.222241  ...  0.263197  0.089408  0.197102  0.162347  1.000000
#
# [12 rows x 12 columns]

# %%
sns.heatmap(df_c.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df_c['FWI']);
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
# Monthly Fire Analysis of Sidi- Bel Regions

df_temp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df);

plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi- Bel Regions",weight='bold');

# %%
## Monthly Fire Analysis of Brjaia Regions

dftemp=df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)

plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Brjaia Regions",weight='bold');

# %%
X=df_c.drop('FWI',axis=1)
y=df['FWI']

X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

X_train.shape,X_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC  ...        DC       ISI       BUI   Classes    Region
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  ...  0.390684  0.629848  0.473609  0.542141  0.254549
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023  ... -0.236078 -0.717804 -0.362317 -0.456876 -0.394665
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  ...  0.096576 -0.023558  0.035633 -0.082570 -0.199969
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491  ... -0.302341 -0.345707 -0.300964 -0.369357 -0.059022
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  ...  0.524101  0.750799  0.607210  0.781259  0.249514
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  ...  0.868647  0.685656  0.983175  0.617273  0.212582
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  ...  1.000000  0.513701  0.942414  0.543581 -0.060838
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  ...  0.513701  1.000000  0.643818  0.742977  0.296441
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  ...  0.942414  0.643818  1.000000  0.612239  0.114897
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  ...  0.543581  0.742977  0.612239  1.000000  0.188837
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  ... -0.060838  0.296441  0.114897  0.188837  1.000000
#
# [11 rows x 11 columns]

# %%
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True);

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i,j]) >  threshold):
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(X_train,0.90)

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 10), (61, 10))

# %% [markdown]
# # Standardizing Data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]])

# %%
# Box plot to understand the effect of Standard Scaler

plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
linreg=LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred=linreg.predict(X_test)
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# 0.5170107980662426
# 0.9830565611009444

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error,r2_score
lasso=Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred=lasso.predict(X_test)
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# 1.1257992990774721
# 0.9498931628519823

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error,r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test)
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# 0.5292519766274829
# 0.9824051915524249

# %% [markdown]
# ## ElasticNet

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error,r2_score
elasticNet=ElasticNet()
elasticNet.fit(X_train_scaled,y_train)
y_pred=elasticNet.predict(X_test)
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
plt.scatter(y_test,y_pred)
# Out:
# 1.770425552142529
# 0.8887824924177792
