# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\HP\Downloads\placement (1).csv")
dataset.head()
# Out:
#    cgpa  score  placed
# 0  5.34   5.29       0
# 1  8.51   6.50       1
# 2  6.97   8.41       1
# 3  8.26   6.80       1
# 4  9.40   7.52       1

# %%
sns.scatterplot(x='cgpa',y='score',data=dataset,hue='placed');

# %%
x=dataset.iloc[:,:-1]
y=dataset['placed']

# %%
from sklearn.preprocessing import PolynomialFeatures

pf=PolynomialFeatures(degree=3)

# %%
pf.fit(x)
x=pd.DataFrame(pf.transform(x))
# x.head(3)
x.shape
# Out:
# (100, 10)
